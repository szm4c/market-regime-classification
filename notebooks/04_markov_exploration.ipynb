# %% [markdown]
# # Config

# %%
# Set dark mode as default
import matplotlib.pyplot as plt
import plotly.io as pio
plt.style.use("dark_background")
pio.templates.default = "plotly_dark"

# Imports
from warnings import catch_warnings, filterwarnings
from itertools import product
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
from statsmodels.tools.sm_exceptions import InterpolationWarning
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import f1_score, balanced_accuracy_score, confusion_matrix, classification_report

from market_regime.data import get_data
from market_regime.features import MarkovFeatureBuilder
from market_regime.models import MarkovOccupancyModel
from market_regime.pipelines.base import RegimePipeline

# %% [markdown]
# # Data

# %% [markdown]
# ### data import

# %%
# Data import (with labels)
df = get_data()

# %%
rp = RegimePipeline(MarkovFeatureBuilder(), MarkovOccupancyModel())

# %%
rp.fit(df)
# Out:
# RegimePipeline(feature_builder=<market_regime.features.markov_features.MarkovFeatureBuilder object at 0x000001AF7EC4F230>, estimator=<market_regime.models.markov_occupancy.MarkovOccupancyModel object at 0x000001AF7EC4F380>)

# %%
rp.predict(df)
# Out:
# trading_date
# 2015-11-30    0
# 2015-12-01    0
# 2015-12-02    0
# 2015-12-03    0
# 2015-12-04    0
#              ..
# 2024-11-22    0
# 2024-11-25    0
# 2024-11-26    0
# 2024-11-27    0
# 2024-11-28    0
# Name: prediction, Length: 2305, dtype: int64

# %% [markdown]
# # OOS Prediction

# %%
rp = RegimePipeline(MarkovFeatureBuilder(), MarkovOccupancyModel())
oos_days = df[df["delivery_date"] >= "2019-01-01"].index
preds = []
i = 0
for d in tqdm(oos_days, desc="OOS Prediction:"):
    df_train = df.loc[: d - pd.Timedelta(days=1), :]
    df_test = df.loc[[d], :]
    rp.fit(df_train)
    pred = rp.predict(df_test)
    preds.append(pred)
oos_pred = pd.concat(preds).sort_index()
# Out:
# OOS Prediction::   0%|          | 0/1537 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       6 df_train = df.loc[: d - pd.Timedelta(days=1), :]
#       7 df_test = df.loc[[d], :]
# ----> 8 rp.fit(df_train)
#       9 pred = rp.predict(df_test)
#      10 preds.append(pred)
#
# File C:\Code\repos\market-regime-classification\src\market_regime\pipelines\base.py:26, in RegimePipeline.fit(self, df_train)
#      23 if y_train is None:
#      24     raise ValueError("Training requires labels (y), but got None.")
# ---> 26 self.estimator.fit(x_train, y_train)
#      28 return self
#
# File C:\Code\repos\market-regime-classification\src\market_regime\models\markov_occupancy.py:48, in MarkovOccupancyModel.fit(self, x, y)
#      40 r = np.asarray(x).ravel()
#      42 mod = MarkovRegression(
#      43     r,
#      44     k_regimes=self.k_regimes,
#      45     trend=self.trend,
#      46     switching_variance=self.switching_variance,
#      47 )
# ---> 48 self.res_ = mod.fit(disp=False, maxiter=self.maxiter)
#      49 self.fitted = True
#      51 # Transition matrix P (k x k)
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_switching.py:1125, in MarkovSwitching.fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, em_iter, search_reps, search_iter, search_scale, **kwargs)
#    1123 # Maximum likelihood estimation by scoring
#    1124 fargs = (False,)
# -> 1125 mlefit = super().fit(start_params, method=method,
#    1126                      fargs=fargs,
#    1127                      maxiter=maxiter,
#    1128                      full_output=full_output,
#    1129                      disp=disp, callback=callback,
#    1130                      skip_hessian=True, **kwargs)
#    1132 # Just return the fitted parameters if requested
#    1133 if return_params:
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\base\model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\base\optimizer.py:245, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     242     fit_funcs.update(extra_fit_funcs)
#     244 func = fit_funcs[method]
# --> 245 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     246                      disp=disp, maxiter=maxiter, callback=callback,
#     247                      retall=retall, full_output=full_output,
#     248                      hess=hessian)
#     250 optim_settings = {'optimizer': method, 'start_params': start_params,
#     251                   'maxiter': maxiter, 'full_output': full_output,
#     252                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     253                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     254 optim_settings.update(kwargs)
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\base\optimizer.py:540, in _fit_bfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     538 norm = kwargs.setdefault('norm', np.inf)
#     539 epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 540 retvals = optimize.fmin_bfgs(f, start_params, score, args=fargs,
#     541                              gtol=gtol, norm=norm, epsilon=epsilon,
#     542                              maxiter=maxiter, full_output=full_output,
#     543                              disp=disp, retall=retall, callback=callback)
#     544 if full_output:
#     545     if not retall:
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_optimize.py:1330, in fmin_bfgs(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback, xrtol, c1, c2, hess_inv0)
#    1318 opts = {'gtol': gtol,
#    1319         'norm': norm,
#    1320         'eps': epsilon,
#    (...)   1326         'c2': c2,
#    1327         'hess_inv0': hess_inv0}
#    1329 callback = _wrap_callback(callback)
# -> 1330 res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#    1332 if full_output:
#    1333     retlist = (res['x'], res['fun'], res['jac'], res['hess_inv'],
#    1334                res['nfev'], res['njev'], res['status'])
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_optimize.py:1443, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, workers, **unknown_options)
#    1440 pk = -np.dot(Hk, gfk)
#    1441 try:
#    1442     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1443              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1444                                   old_fval, old_old_fval, amin=1e-100,
#    1445                                   amax=1e100, c1=c1, c2=c2)
#    1446 except _LineSearchError:
#    1447     # Line search failed to find a better solution.
#    1448     warnflag = 2
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_optimize.py:1172, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1158 """
#    1159 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1160 suitable step length is not found, and raise an exception if a
#    (...)   1167
#    1168 """
#    1170 extra_condition = kwargs.pop('extra_condition', None)
# -> 1172 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1173                          old_fval, old_old_fval,
#    1174                          **kwargs)
#    1176 if ret[0] is not None and extra_condition is not None:
#    1177     xp1 = xk + ret[0] * pk
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_linesearch.py:93, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      89     return np.dot(gval[0], pk)
#      91 derphi0 = np.dot(gfk, pk)
# ---> 93 stp, fval, old_fval = scalar_search_wolfe1(
#      94         phi, derphi, old_fval, old_old_fval, derphi0,
#      95         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      97 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_linesearch.py:170, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     167 maxiter = 100
#     169 dcsrch = DCSRCH(phi, derphi, c1, c2, xtol, amin, amax)
# --> 170 stp, phi1, phi0, task = dcsrch(
#     171     alpha1, phi0=phi0, derphi0=derphi0, maxiter=maxiter
#     172 )
#     174 return stp, phi1, phi0
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_dcsrch.py:256, in DCSRCH.__call__(self, alpha1, phi0, derphi0, maxiter)
#     254     alpha1 = stp
#     255     phi1 = self.phi(stp)
# --> 256     derphi1 = self.derphi(stp)
#     257 else:
#     258     break
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_linesearch.py:87, in line_search_wolfe1.<locals>.derphi(s)
#      86 def derphi(s):
# ---> 87     gval[0] = fprime(xk + s*pk, *args)
#      88     gc[0] += 1
#      89     return np.dot(gval[0], pk)
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:391, in ScalarFunction.grad(self, x)
#     389 if not np.array_equal(x, self.x):
#     390     self._update_x(x)
# --> 391 self._update_grad()
#     392 return self.g
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:366, in ScalarFunction._update_grad(self)
#     364 if self._orig_grad in FD_METHODS:
#     365     self._update_fun()
# --> 366 self.g = self._wrapped_grad(self.x, f0=self.f)
#     367 self.g_updated = True
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:39, in _ScalarGradWrapper.__call__(self, x, f0, **kwds)
#      35 def __call__(self, x, f0=None, **kwds):
#      36     # Send a copy because the user may overwrite it.
#      37     # The user of this class might want `x` to remain unchanged.
#      38     if callable(self.grad):
# ---> 39         g = np.atleast_1d(self.grad(np.copy(x), *self.args))
#      40     elif self.grad in FD_METHODS:
#      41         g, dct = approx_derivative(
#      42             self.fun,
#      43             x,
#      44             f0=f0,
#      45             **self.finite_diff_options,
#      46         )
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\base\model.py:545, in LikelihoodModel.fit.<locals>.score(params, *args)
#     544 def score(params, *args):
# --> 545     return -self.score(params, *args) / nobs
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_switching.py:992, in MarkovSwitching.score(self, params, transformed)
#     979 """
#     980 Compute the score function at params.
#     981
#    (...)    988     Whether or not `params` is already transformed. Default is True.
#     989 """
#     990 params = np.array(params, ndmin=1)
# --> 992 return approx_fprime_cs(params, self.loglike, args=(transformed,))
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tools\numdiff.py:251, in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     249 increments = np.identity(n) * 1j * epsilon
#     250 # TODO: see if this can be vectorized, but usually dim is small
# --> 251 partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
#     252             for i, ih in enumerate(increments)]
#     254 return np.array(partials).T
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_switching.py:976, in MarkovSwitching.loglike(self, params, transformed)
#     964 def loglike(self, params, transformed=True):
#     965     """
#     966     Loglikelihood evaluation
#     967
#    (...)    974         Whether or not `params` is already transformed. Default is True.
#     975     """
# --> 976     return np.sum(self.loglikeobs(params, transformed))
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_switching.py:960, in MarkovSwitching.loglikeobs(self, params, transformed)
#     957 if not transformed:
#     958     params = self.transform_params(params)
# --> 960 results = self._filter(params)
#     962 return results[5]
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_switching.py:776, in MarkovSwitching._filter(self, params, regime_transition)
#     772 initial_probabilities = self.initial_probabilities(
#     773     params, regime_transition)
#     775 # Compute the conditional likelihoods
# --> 776 conditional_loglikelihoods = self._conditional_loglikelihoods(params)
#     778 # Apply the filter
#     779 return ((regime_transition, initial_probabilities,
#     780          conditional_loglikelihoods) +
#     781         cy_hamilton_filter_log(
#     782             initial_probabilities, regime_transition,
#     783             conditional_loglikelihoods, self.order))
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_regression.py:183, in MarkovRegression._conditional_loglikelihoods(self, params)
#     178 """
#     179 Compute loglikelihoods conditional on the current period's regime
#     180 """
#     182 # Get residuals
# --> 183 resid = self._resid(params)
#     185 # Compute the conditional likelihoods
#     186 variance = params[self.parameters['variance']].squeeze()
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_regression.py:173, in MarkovRegression._resid(self, params)
#     172 def _resid(self, params):
# --> 173     predict = np.repeat(self.predict_conditional(params),
#     174                         self.k_regimes, axis=1)
#     175     return self.endog - predict
#
# File c:\Code\repos\market-regime-classification\.venv\Lib\site-packages\statsmodels\tsa\regime_switching\markov_regression.py:168, in MarkovRegression.predict_conditional(self, params)
#     166     if self._k_exog > 0:
#     167         coeffs = params[self.parameters[i, 'exog']]
# --> 168         predict[i] = np.dot(self.exog, coeffs)
#     170 return predict[:, None, :]
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y_true = df.loc[oos_pred.index, "target"].astype(int)
y_pred = oos_pred.astype(int)

macro_f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)
bal_acc = balanced_accuracy_score(y_true, y_pred)

cm = confusion_matrix(y_true, y_pred, labels=[-1, 0, 1])
cm_df = pd.DataFrame(cm, index=["true_-1", "true_0", "true_1"], columns=["pred_-1", "pred_0", "pred_1"])

print(f"OOS Macro-F1:          {macro_f1:.4f}")
print(f"OOS Balanced Accuracy: {bal_acc:.4f}\n")

print("Confusion matrix (rows=true, cols=pred):")
display(cm_df)

print("\nClass distribution:")
print("y_true:\n", y_true.value_counts(normalize=True).sort_index())
print("\ny_pred:\n", y_pred.value_counts(normalize=True).sort_index())

print("\nClassification report:")
print(classification_report(y_true, y_pred, labels=[-1, 0, 1], zero_division=0))

# small preview
oos_eval = pd.DataFrame({"y_true": y_true, "y_pred": y_pred})
display(oos_eval.head(20))
# Out:
# OOS Macro-F1:          0.1617
# OOS Balanced Accuracy: 0.3327
#
# Confusion matrix (rows=true, cols=pred):
#          pred_-1  pred_0  pred_1
# true_-1        0     611       4
# true_0         0     491       1
# true_1         0     430       0
# Class distribution:
# y_true:
#  target
# -1    0.400130
#  0    0.320104
#  1    0.279766
# Name: proportion, dtype: float64
#
# y_pred:
#  prediction
# 0    0.996747
# 1    0.003253
# Name: proportion, dtype: float64
#
# Classification report:
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00       615
#            0       0.32      1.00      0.49       492
#            1       0.00      0.00      0.00       430
#
#     accuracy                           0.32      1537
#    macro avg       0.11      0.33      0.16      1537
# weighted avg       0.10      0.32      0.16      1537
#               y_true  y_pred
# trading_date
# 2018-11-30        -1       0
# 2018-12-03        -1       1
# 2018-12-04        -1       1
# 2018-12-05        -1       0
# 2018-12-06         0       0
# 2018-12-07        -1       0
# 2018-12-10         0       0
# 2018-12-11         0       0
# 2018-12-12        -1       0
# 2018-12-13        -1       0
# 2018-12-14        -1       0
# 2018-12-17        -1       1
# 2018-12-18         0       1
# 2018-12-19        -1       0
# 2018-12-20        -1       0
# 2018-12-21        -1       0
# 2018-12-24        -1       1
# 2018-12-27        -1       0
# 2018-12-28        -1       0
# 2018-12-31         0       0
